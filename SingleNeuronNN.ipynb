# %% [markdown]
# <a href="https://colab.research.google.com/github/Chercas/ML_2021/blob/main/SingleNeuronNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
celcius_q = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit_a = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# %%
l0 = tf.keras.layers.Dense(units=1, input_shape=[1])

# %%
model = tf.keras.Sequential([l0])

# %%
model.compile(loss='mse', optimizer=tf.keras.optimizers.Adam(learning_rate=0.1))

# %%
history = model.fit(celcius_q, fahrenheit_a, epochs=500, verbose=False)
print('Finished!')
# Out:
# Finished!

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(18, 12))
plt.plot(history.history['loss'])
plt.show()

# %%
print(model.predict([100]))
# Out:
# [[211.3061]]

# %%
print(l0.get_weights())
# Out:
# [array([[1.8248391]], dtype=float32), array([28.822184], dtype=float32)]
